# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
ver=pd.read_csv("crm.csv")
print ver
# Out:
#    leadname salesperson status
# 0     Rohan       Nanda  Loose
# 1  Mitchell      Dinesh    Win
# 2     Marry      Kathir    Win
# 3     Logan       Nanda  Loose
# 4     Barby       Nanda  Loose
# 5       Kai       Nanda    Win
# 6       Leo      Kathir  Loose
# 7    Daemon      Dinesh  Loose
# 8      Lyka      Dinesh  Loose
# 9    Farooq      Kathir  Loose

# %%
ver.status.value_counts().plot(kind='bar')

# %%
ver.leadno.value_counts().plot(kind='box')

# %%
import seaborn
g = seaborn.factorplot("id", "leadowner", "leadno", ver, kind="box",palette="PRGn",aspect=2.25)
g.set(ylim=(0, 600))

# %%
seaborn.factorplot("leadowner", data=ver, size=3,aspect=2)
